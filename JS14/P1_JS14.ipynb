# %% [markdown]
# ## Langkah 1 - Import Library

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ## Langkah 2 - Pra Pengolahan Data
# Pada tahap ini kita akan sedikit melakukan manipulasi pada citra yang digunakan. Manipulasi yang dilakukan diantaranya adalah normalisasi nilai piksel, koreksi kemiringan, pembesaran (zoom), dan flip.

# %% [markdown]
# ### Langkah 2.1. Pra Pengolahan Data Training

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                shear_range = 0.2,
                                zoom_range = 0.2,
                                horizontal_flip = True)
training_set = train_datagen.flow_from_directory('../Dataset/training_set',
                                                target_size = (64, 64),
                                                batch_size = 32,
                                                class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Langkah 2.2. Pra Pengolahan Data Testing

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('../Dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Langkah 3 - Pembuatan Model CNN

# %% [markdown]
# ### Langkah 3.1.  - Inisiasi Model CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Langkah 3.2. - Pembuatan Layer Konvolusi 1

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# ### Langkah 3.3 - Pembuatan Layer Pooling 1

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Langkah 3.4 - Pembuatan Layer Konvolusi 2 dan Pooling 2

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Langkah 3.5 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Langkah 3.6 - Fully Connected Layer 1 (Input)

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Langkah 3.7 - Fully Connected Layer 2 (Output)

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ### Langkah 3.8 - Compile Model CNN
# Penggunaan loss function binary crossentropy dikarenakan kita hanya melakukan klasifikasi pada dua kelas, yaitu kucing dan anjing.

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ## Langkah 4 - Fit CNN

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 127s 504ms/step - accuracy: 0.5810 - loss: 0.6693 - val_accuracy: 0.5845 - val_loss: 0.7023
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 127s 504ms/step - accuracy: 0.5810 - loss: 0.6693 - val_accuracy: 0.5845 - val_loss: 0.7023
# Epoch 2/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 78ms/step - accuracy: 0.6719 - loss: 0.6087 - val_accuracy: 0.6740 - val_loss: 0.5942
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 78ms/step - accuracy: 0.6719 - loss: 0.6087 - val_accuracy: 0.6740 - val_loss: 0.5942
# Epoch 3/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.7066 - loss: 0.5648 - val_accuracy: 0.7340 - val_loss: 0.5417
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.7066 - loss: 0.5648 - val_accuracy: 0.7340 - val_loss: 0.5417
# Epoch 4/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0
25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.8733 - loss: 0.2982 - val_accuracy: 0.8105 - val_loss: 0.4921
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 77ms/step - accuracy: 0.8733 - loss: 0.2982 - val_accuracy: 0.8105 - val_loss: 0.4921
# Epoch 18/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.8816 - loss: 0.2853 - val_accuracy: 0.7805 - val_loss: 0.5553
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 79ms/step - accuracy: 0.8816 - loss: 0.2853 - val_accuracy: 0.7805 - val_loss: 0.5553
# Epoch 19/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.8834 - loss: 0.2758 - val_accuracy: 0.7800 - val_loss: 0.5532
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 20s 82ms/step - accuracy: 0.8834 - loss: 0.2758 - val_accuracy: 0.7800 - val_loss: 0.5532
# Epoch 20/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 94ms/step - accuracy: 0.8842 - loss: 0.2670 - val_accuracy: 0.8020 - val_loss: 0.5028
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 24s 94ms/step - accuracy: 0.8842 - loss: 0.2670 - val_accuracy: 0.8020 - val_loss: 0.5028
# Epoch 21/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 36s 144ms/step - accuracy: 0.9016 - loss: 0.2414 - val_accuracy: 0.7920 - val_loss: 0.5614
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 36s 144ms/step - accuracy: 0.9016 - loss: 0.2414 - val_accuracy: 0.7920 - val_loss: 0.5614
# Epoch 22/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - accuracy: 0.9112 - loss: 0.2188 - val_accuracy: 0.7775 - val_loss: 0.6215
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - accuracy: 0.9112 - loss: 0.2188 - val_accuracy: 0.7775 - val_loss: 0.6215
# Epoch 23/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - accuracy: 0.9079 - loss: 0.2215 - val_accuracy: 0.7935 - val_loss: 0.5562
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 27s 108ms/step - accuracy: 0.9079 - loss: 0.2215 - val_accuracy: 0.7935 - val_loss: 0.5562
# Epoch 24/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - accuracy: 0.9165 - loss: 0.2060 - val_accuracy: 0.8015 - val_loss: 0.5811
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 28s 114ms/step - accuracy: 0.9165 - loss: 0.2060 - val_accuracy: 0.8015 - val_loss: 0.5811
# Epoch 25/25
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 36s 146ms/step - accuracy: 0.9226 - loss: 0.1942 - val_accuracy: 0.7970 - val_loss: 0.5628
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 36s 146ms/step - accuracy: 0.9226 - loss: 0.1942 - val_accuracy: 0.7970 - val_loss: 0.5628

# %% [markdown]
# ## Langkah 5 - Prediksi dengan 1 Citra
# Pada langkah ini, kita akan mencoba melakukan prediksi pada 1 citra anjing dan kucing.

# %%
import numpy as np
from keras.preprocessing import image
test_image = image.load_img('../Dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = image.img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
  
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# dog
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# dog
