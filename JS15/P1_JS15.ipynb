# %% [markdown]
# ## Langkah 1: Import Library dan Mount Google Drive
#
# Langkah pertama adalah mengimpor pustaka yang diperlukan untuk pengolahan citra, machine learning, dan deep learning, serta menghubungkan Google Colab dengan Google Drive.

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import cv2

from skimage.feature import hog
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models

# Uncomment jika menggunakan Google Colab
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ## Langkah 2: Load Dataset
#
# Membaca gambar dari direktori training dan testing, lalu menyimpannya dalam list bersama dengan labelnya.
#
# **Catatan:** Sesuaikan path dengan lokasi folder `images` di komputer Anda.

# %%
# Load images and labels from a directory structure
def load_dataset(img_dir):
    p = Path(img_dir)
    img_list = []
    for folder in p.glob('*'):
        label = folder.name
        for file in folder.glob('*.jpg'):
            img = cv2.imread(str(file))
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img_list.append((img, label))
    return img_list

# Sesuaikan path dengan lokasi dataset Anda
train_dir = "../Dataset/images/training/"
test_dir  = "../Dataset/images/test/"

train_img = load_dataset(train_dir)
test_img  = load_dataset(test_dir)

print(f"Jumlah data training: {len(train_img)}")
print(f"Jumlah data testing: {len(test_img)}")
# Out:
# Jumlah data training: 240
# Jumlah data testing: 160

# %% [markdown]
# ## Langkah 3: Preprocessing (Resize & Label Encoding)
#
# Mengubah ukuran gambar menjadi 256x256 piksel dan mengubah label teks ('day'/'night') menjadi angka biner (1/0).

# %%
# Preprocess images: resize and encode labels
def resize_image(img, size=(256,256)):
    return cv2.resize(img, size)

def label_encoder(label):
    return 1 if label == 'day' else 0

def preprocess(img_list):
    X = []
    y = []
    for img, label in img_list:
        img_std = resize_image(img)
        X.append(img_std)
        y.append(label_encoder(label))
    return X, y

X_train_img, y_train = preprocess(train_img)
X_test_img,  y_test  = preprocess(test_img)

# %% [markdown]
# ## Langkah 4: Ekstraksi Fitur HOG (Histogram of Oriented Gradients)
#
# Mengekstraksi fitur bentuk dan tekstur dari gambar menggunakan metode HOG.

# %%
# Extract HOG features
def extract_hog(X_imgs):
    feats = []
    for img in X_imgs:
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        hog_feat = hog(gray,
                       orientations=9,
                       pixels_per_cell=(8,8),
                       cells_per_block=(2,2),
                       block_norm='L2-Hys',
                       visualize=False,
                       feature_vector=True)
        feats.append(hog_feat)
    return np.array(feats)

X_train_feat = extract_hog(X_train_img)
X_test_feat  = extract_hog(X_test_img)

print(f"Shape fitur training: {X_train_feat.shape}")
print(f"Shape fitur testing: {X_test_feat.shape}")
# Out:
# Shape fitur training: (240, 34596)
# Shape fitur testing: (160, 34596)

# %% [markdown]
# ## Langkah 5: Normalisasi Fitur
#
# Menstandarisasi fitur agar memiliki rata-rata 0 dan variansi 1 menggunakan `StandardScaler`.

# %%
# Normalize features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_feat)
X_test_scaled  = scaler.transform(X_test_feat)

# %% [markdown]
# ## Langkah 6: Split Data Training & Validation
#
# Memisahkan data training menjadi data train dan validation.

# %%
# Split training data for validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train_scaled, y_train,
    test_size=0.2,
    random_state=42
)

print(f"Jumlah data train: {len(X_train)}")
print(f"Jumlah data validation: {len(X_val)}")
# Out:
# Jumlah data train: 192
# Jumlah data validation: 48

# %% [markdown]
# ## Langkah 7: Konversi Label ke Numpy Array
#
# Mengubah list label menjadi format numpy array agar kompatibel dengan TensorFlow/Keras.

# %%
# Convert labels to numpy arrays (required for Keras)
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# %% [markdown]
# ## Langkah 8: Membangun Arsitektur Model Neural Network
#
# Membuat model Sequential dengan 3 layer (Input, Hidden Layers dengan ReLU, dan Output Layer dengan Sigmoid).

# %%
# Build a simple feedforward neural network
# Define model architecture
# input_dim is the number of features in the dataset
# Hidden layer -> 128 neurons, ReLU activation
# Hidden layer -> 64 neurons, ReLU activation
# Output layer -> 1 neuron, Sigmoid activation (for binary classification)
input_dim = X_train.shape[1]

model = models.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 128)            │     4,428,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,436,737 (16.92 MB)
#  Trainable params: 4,436,737 (16.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Langkah 9: Training Model
#
# Melatih model menggunakan data training selama 20 epoch.

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - accuracy: 0.7083 - loss: 1.3205 - val_accuracy: 0.9583 - val_loss: 0.1925
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9948 - loss: 0.0091 - val_accuracy: 0.9792 - val_loss: 0.3693
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 1.0000 - loss: 0.0054 - val_accuracy: 0.9792 - val_loss: 0.4540
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 7.1561e-04 - val_accuracy: 0.9792 - val_loss: 0.4858
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 2.7590e-04 - val_accuracy: 0.9792 - val_loss: 0.4996
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.1011e-04 - val_accuracy: 0.9792 - val_loss: 0.5056
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 6.3747e-05 - val_accuracy: 0.9792 - val_loss: 0.5087
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 3.9863e-05 - val_accuracy: 0.9792 - val_loss: 0.5105
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 2.9375e-05 - val_accuracy: 0.9792 - val_loss: 0.5115
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 1.0000 - loss: 2.3471e-05 - val_accuracy: 0.9792 - val_loss: 0.5121
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.9714e-05 - val_accuracy: 0.9792 - val_loss: 0.5125
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 1.7220e-05 - val_accuracy: 0.9792 - val_loss: 0.5127
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 1.0000 - loss: 1.5531e-05 - val_accuracy: 0.9792 - val_loss: 0.5128
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.3977e-05 - val_accuracy: 0.9792 - val_loss: 0.5130
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 1.0000 - loss: 1.2782e-05 - val_accuracy: 0.9792 - val_loss: 0.5131
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 1.0000 - loss: 1.1890e-05 - val_accuracy: 0.9792 - val_loss: 0.5131
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 1.0000 - loss: 1.0977e-05 - val_accuracy: 0.9792 - val_loss: 0.5132
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 1.0258e-05 - val_accuracy: 0.9792 - val_loss: 0.5133
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 1.0000 - loss: 9.6071e-06 - val_accuracy: 0.9792 - val_loss: 0.5133
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 9.0499e-06 - val_accuracy: 0.9792 - val_loss: 0.5134

# %% [markdown]
# ## Langkah 10: Evaluasi Model
#
# Menguji performa model pada data testing.

# %%
# Evaluate the model on test data
test_loss, test_acc = model.evaluate(X_test_scaled, y_test)
print("Akurasi Test:", test_acc)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8625 - loss: 1.2179
# Akurasi Test: 0.862500011920929

# %% [markdown]
# ## Langkah 11: Prediksi dan Laporan Klasifikasi serta Visualisasi
#
# Membuat prediksi pada data test dan menampilkan classification report serta confusion matrix.

# %%
# Generate classification report and confusion matrix
y_pred_prob = model.predict(X_test_scaled)
y_pred = (y_pred_prob > 0.5).astype(int)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
#               precision    recall  f1-score   support
#
#            0       0.94      0.78      0.85        80
#            1       0.81      0.95      0.87        80
#
#     accuracy                           0.86       160
#    macro avg       0.87      0.86      0.86       160
# weighted avg       0.87      0.86      0.86       160
#
# [[62 18]
#  [ 4 76]]

# %%
# Visualize training history
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Langkah 12: Menyimpan Model dan Scaler
#
# Menyimpan model yang sudah dilatih ke dalam format `.h5` dan scaler ke format `.pkl` untuk penggunaan deployment.

# %%
# Save the trained model
import pickle

# 1. Simpan Model
# Menggunakan format .h5
model.save('day_night_model.h5')
print("✅ Model berhasil disimpan sebagai: day_night_model.h5")

# 2. Simpan Scaler
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
print("✅ Scaler berhasil disimpan sebagai: scaler.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model berhasil disimpan sebagai: day_night_model.h5
# ✅ Scaler berhasil disimpan sebagai: scaler.pkl
